# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Mumbai_House_Prices.csv')

# %%
data.head( )
# Out:
#    bhk       type                              locality  area  price  \
# 0    3  Apartment   Lak And Hanware The Residency Tower   685   2.50
# 1    2  Apartment     Radheya Sai Enclave Building No 2   640  52.51
# 2    2  Apartment                         Romell Serene   610   1.73
# 3    2  Apartment  Soundlines Codename Urban Rainforest   876  59.98
# 4    2  Apartment                         Origin Oriana   659  94.11
#
#   price_unit  money in Cr          region
# 0         Cr       2.5000    Andheri West
# 1          L       0.5251    Naigaon East
# 2         Cr       1.7300   Borivali West
# 3          L       0.5998          Panvel
# 4          L       0.9411  Mira Road East

# %%
data.shape
# Out:
# (76038, 8)

# %%
data.info
# Out:
# <bound method DataFrame.info of        bhk       type                              locality  area  price  \
# 0        3  Apartment   Lak And Hanware The Residency Tower   685   2.50
# 1        2  Apartment     Radheya Sai Enclave Building No 2   640  52.51
# 2        2  Apartment                         Romell Serene   610   1.73
# 3        2  Apartment  Soundlines Codename Urban Rainforest   876  59.98
# 4        2  Apartment                         Origin Oriana   659  94.11
# ...    ...        ...                                   ...   ...    ...
# 76033    3  Apartment                     Parinee Liva Roca  1527   7.00
# 76034    5  Apartment                     Parinee Liva Roca  3049  12.00
# 76035    4  Apartment                         Lodha Seaview  3313  10.00
# 76036    2  Apartment                        Hubtown Serene  1305   4.25
# 76037    5  Apartment              Sunteck Signature Island  5200  25.00
#
#       price_unit  money in Cr                region
# ...

# %%
for column in data.columns:
    print(data[column].value_counts())
    print("*"*20)
# Out:
# bhk
# 2     31429
# 1     24613
# 3     15273
# 4      3934
# 5       606
# 6       148
# 7        16
# 8         8
# 10        6
# 9         5
# Name: count, dtype: int64
# ********************
# type
# Apartment            74854
# Studio Apartment       882
# Villa                  226
# Independent House       73
# Penthouse                3
# Name: count, dtype: int64
# ********************
# locality
# Hiranandani Meadows         861
# Sheth Avalon                516
# T Bhimjyani The Verraton    499
# ACME Ozone Phase 2          467
# Runwal Gardens              389
#                            ...
# Cosmos Angel Tower            1
# Sheth Konark Empress          1
# Shree Chamunda Garden         1
# Vega Platinum Enclave         1
# Omkar Puram                   1
# Name: count, Length: 9782, dtype: int64
# ********************
# area
# 650     1662
# 1050    1381
# 1100    1151
# 1650    1041
# 750      950
#         ...
# 2875       1
# 1987       1
# 1749       1
# ...

# %%
data.isna().sum()
# Out:
# bhk            0
# type           0
# locality       0
# area           0
# price          0
# price_unit     0
# money in Cr    0
# region         0
# dtype: int64

# %%
# data.drop(columns=['locality'],inplace=True)

# %%
data.describe()
# Out:
#                 bhk          area        price   money in Cr
# count  76038.000000  76038.000000  76038.00000  76038.000000
# mean       2.015111   1024.536850     29.38227      1.684178
# std        0.922754    670.276165     32.90345      2.176655
# min        1.000000    127.000000      1.00000      0.044900
# 25%        1.000000    640.000000      1.75000      0.640000
# 50%        2.000000    872.000000      5.50000      1.100000
# 75%        3.000000   1179.000000     59.00000      1.940000
# max       10.000000  16000.000000     99.99000     60.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76038 entries, 0 to 76037
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   bhk          76038 non-null  int64
#  1   type         76038 non-null  object
#  2   locality     76038 non-null  object
#  3   area         76038 non-null  int64
#  4   price        76038 non-null  float64
#  5   price_unit   76038 non-null  object
#  6   money in Cr  76038 non-null  float64
#  7   region       76038 non-null  object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.6+ MB

# %%
data['bhk'].value_counts()
# Out:
# bhk
# 2     31429
# 1     24613
# 3     15273
# 4      3934
# 5       606
# 6       148
# 7        16
# 8         8
# 10        6
# 9         5
# Name: count, dtype: int64

# %%
data['region'].value_counts()
# Out:
# region
# Thane West             14868
# Mira Road East          9902
# Dombivali               3041
# Kandivali East          2568
# Kharghar                2362
#                        ...
# Adaigaon                   1
# Sector-4 New Panvel        1
# Versova                    1
# Sector 6 Kamothe           1
# Pen                        1
# Name: count, Length: 228, dtype: int64

# %%
data['area'].unique()
# Out:
# array([ 685,  640,  610, ..., 1974, 1634, 3049])

# %%
data['Price_per_sqft']= data['money in Cr'] * 10000000/data['area']

# %%
data['Price_per_sqft']
# Out:
# 0        36496.350365
# 1         8204.687500
# 2        28360.655738
# 3         6847.031963
# 4        14280.728376
#              ...
# 76033    45841.519319
# 76034    39357.166284
# 76035    30184.123151
# 76036    32567.049808
# 76037    48076.923077
# Name: Price_per_sqft, Length: 76038, dtype: float64

# %%
data.describe()
# Out:
#                 bhk          area        price   money in Cr  Price_per_sqft
# count  76038.000000  76038.000000  76038.00000  76038.000000    76038.000000
# mean       2.015111   1024.536850     29.38227      1.684178    15118.812074
# std        0.922754    670.276165     32.90345      2.176655     9332.899565
# min        1.000000    127.000000      1.00000      0.044900      646.766169
# 25%        1.000000    640.000000      1.75000      0.640000     8571.428571
# 50%        2.000000    872.000000      5.50000      1.100000    13000.000000
# 75%        3.000000   1179.000000     59.00000      1.940000    19496.115827
# max       10.000000  16000.000000     99.99000     60.000000   182307.692308

# %%
data['region'].value_counts()
# Out:
# region
# Thane West             14868
# Mira Road East          9902
# Dombivali               3041
# Kandivali East          2568
# Kharghar                2362
#                        ...
# Adaigaon                   1
# Sector-4 New Panvel        1
# Versova                    1
# Sector 6 Kamothe           1
# Pen                        1
# Name: count, Length: 228, dtype: int64

# %%
data['region'] = data['region'].apply(lambda x: x.strip())
location_count= data['region'].value_counts()

# %%
data['region'].value_counts()
# Out:
# region
# Thane West             14868
# Mira Road East          9902
# Dombivali               3041
# Kandivali East          2568
# Kharghar                2362
#                        ...
# Adaigaon                   1
# Sector-4 New Panvel        1
# Versova                    1
# Sector 6 Kamothe           1
# Pen                        1
# Name: count, Length: 228, dtype: int64

# %%
data.describe()
# Out:
#                 bhk          area        price   money in Cr  Price_per_sqft
# count  76038.000000  76038.000000  76038.00000  76038.000000    76038.000000
# mean       2.015111   1024.536850     29.38227      1.684178    15118.812074
# std        0.922754    670.276165     32.90345      2.176655     9332.899565
# min        1.000000    127.000000      1.00000      0.044900      646.766169
# 25%        1.000000    640.000000      1.75000      0.640000     8571.428571
# 50%        2.000000    872.000000      5.50000      1.100000    13000.000000
# 75%        3.000000   1179.000000     59.00000      1.940000    19496.115827
# max       10.000000  16000.000000     99.99000     60.000000   182307.692308

# %%
(data['area']/data['bhk']).describe()
# Out:
# count    76038.000000
# mean       513.278131
# std        161.417111
# min        127.000000
# 25%        403.500000
# 50%        502.500000
# 75%        600.000000
# max       4930.000000
# dtype: float64

# %%
data = data[((data['area']/data['bhk'])>= 300 )]
data.describe()
# Out:
#                 bhk          area         price   money in Cr  Price_per_sqft
# count  71567.000000  71567.000000  71567.000000  71567.000000    71567.000000
# mean       2.006665   1052.869311     29.012282      1.723879    14946.070563
# std        0.936963    679.476429     32.770510      2.231781     9379.789589
# min        1.000000    300.000000      1.000000      0.044900      646.766169
# 25%        1.000000    651.000000      1.800000      0.645000     8455.882353
# 50%        2.000000    905.000000      5.250000      1.110000    12727.272727
# 75%        3.000000   1200.000000     58.000000      2.000000    19165.727170
# max       10.000000  16000.000000     99.990000     60.000000   182307.692308

# %%
(data['area']/data['bhk']).describe()
# Out:
# count    71567.000000
# mean       528.783193
# std        153.475626
# min        300.000000
# 25%        425.000000
# 50%        516.666667
# 75%        613.500000
# max       4930.000000
# dtype: float64

# %%
data.shape
# Out:
# (71567, 9)

# %%
data.Price_per_sqft.describe()
# Out:
# count     71567.000000
# mean      14946.070563
# std        9379.789589
# min         646.766169
# 25%        8455.882353
# 50%       12727.272727
# 75%       19165.727170
# max      182307.692308
# Name: Price_per_sqft, dtype: float64

# %%
def remove_outliers_sqft(df):
    df_output = pd.DataFrame()
    for key, subdf in df.groupby('region'):
        m = np.mean(subdf.Price_per_sqft)
        sd = np.std(subdf.Price_per_sqft)

        gen_df = subdf[(subdf.Price_per_sqft > (m - sd)) & (subdf.Price_per_sqft <= (m + sd))]
        df_output = pd.concat([df_output, gen_df], ignore_index=True)
    return df_output
data= remove_outliers_sqft(data)
data.describe()
# Out:
#                 bhk          area         price   money in Cr  Price_per_sqft
# count  53744.000000  53744.000000  53744.000000  53744.000000    53744.000000
# mean       1.987645   1053.032283     29.599907      1.597082    14115.205906
# std        0.908908    648.558322     33.245023      1.841076     8101.014757
# min        1.000000    300.000000      1.000000      0.119100     2500.000000
# 25%        1.000000    670.000000      1.750000      0.650000     8327.102804
# 50%        2.000000    927.000000      4.750000      1.100000    12230.215827
# 75%        3.000000   1200.000000     60.000000      1.900000    18032.786885
# max       10.000000  16000.000000     99.990000     55.550000    67307.692308

# %%
data['bhk'].describe()
# Out:
# count    53744.000000
# mean         1.987645
# std          0.908908
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         10.000000
# Name: bhk, dtype: float64

# %%
data.shape
# Out:
# (53744, 9)

# %%
data.drop(columns=['Price_per_sqft'], inplace=True)

# %%
data.head()
# Out:
#    bhk       type             locality  area  price price_unit  money in Cr  \
# 0    2  Apartment  Grace Grace Fluidic   650   2.62         Cr         2.62
# 1    1  Apartment     Limra Burj Qadri   803   2.25         Cr         2.25
# 2    1  Apartment  Hi Rock Kinjal Nine   684   1.70         Cr         1.70
# 3    1  Apartment     Dudhwala Complex   545   1.60         Cr         1.60
# 4    2  Apartment   Lokhandwala Galaxy  1650   3.50         Cr         3.50
#
#      region
# 0  Agripada
# 1  Agripada
# 2  Agripada
# 3  Agripada
# 4  Agripada

# %%
data.to_csv("Cleaned_data.csv")

# %%
data=pd.read_csv('Cleaned_data.csv')

# %%
data["type"].replace({"Apartment": 1, "Studio Apartment": 2,"Villa":3, "Penthouse":4, "Independent House":5}, inplace=True)
print(data.head())
# Out:
#    Unnamed: 0  bhk  type             locality  area  price price_unit  \
# 0           0    2     1  Grace Grace Fluidic   650   2.62         Cr
# 1           1    1     1     Limra Burj Qadri   803   2.25         Cr
# 2           2    1     1  Hi Rock Kinjal Nine   684   1.70         Cr
# 3           3    1     1     Dudhwala Complex   545   1.60         Cr
# 4           4    2     1   Lokhandwala Galaxy  1650   3.50         Cr
#
#    money in Cr    region
# 0         2.62  Agripada
# 1         2.25  Agripada
# 2         1.70  Agripada
# 3         1.60  Agripada
# 4         3.50  Agripada
# C:\Users\mittr\AppData\Local\Temp\ipykernel_6868\672497239.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
X= data.drop(columns=['price','price_unit','money in Cr','locality','region'])
Y= data['money in Cr']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2, random_state=0)
len(X_test)
# Out:
# 10749

# %%
print(X_train.shape)
print(X_test.shape)
len(Y_test)
# Out:
# (42995, 4)
# (10749, 4)
# 10749

# %%
# column_trans = make_column_transformer((OneHotEncoder(handle_unknown='ignore'),['region']),
#                                        remainder='passthrough',sparse_threshold=0)

# %%
scaler = StandardScaler()

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline( scaler, lr)

# %%
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
Y_pred_lr = pipe.predict(X_test)

# %%
r2_score(Y_test, Y_pred_lr)
# Out:
# 0.62693735850144

# %%
lasso = Lasso()

# %%
pipe = make_pipeline(scaler, lasso)

# %%
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
Y_pred_lasso = pipe.predict(X_test)
r2_score(Y_test,Y_pred_lasso)
# Out:
# 0.32182237380030165

# %%
ridge = Ridge()

# %%
pipe = make_pipeline(scaler, ridge)

# %%
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
Y_pred_ridge = pipe.predict(X_test)

# %%
r2_score(Y_test,Y_pred_ridge)
# Out:
# 0.6269380031840968

# %%
print("No Regularization: ", r2_score(Y_test, Y_pred_lr))
print("Lasso: ", r2_score(Y_test, Y_pred_lasso))
print("Ridge: ", r2_score(Y_test, Y_pred_ridge))
# Out:
# No Regularization:  0.62693735850144
# Lasso:  0.32182237380030165
# Ridge:  0.6269380031840968

# %%
data.head()
# Out:
#    Unnamed: 0  bhk  type             locality  area  price price_unit  \
# 0           0    2     1  Grace Grace Fluidic   650   2.62         Cr
# 1           1    1     1     Limra Burj Qadri   803   2.25         Cr
# 2           2    1     1  Hi Rock Kinjal Nine   684   1.70         Cr
# 3           3    1     1     Dudhwala Complex   545   1.60         Cr
# 4           4    2     1   Lokhandwala Galaxy  1650   3.50         Cr
#
#    money in Cr    region
# 0         2.62  Agripada
# 1         2.25  Agripada
# 2         1.70  Agripada
# 3         1.60  Agripada
# 4         3.50  Agripada

# %%
data['type'].unique()
# Out:
# array([1, 2, 5, 3, 4])

# %%
unique_values = ['Agripada', 'Airoli', 'Ambarnath', 'Ambernath East', 'Ambernath West', 'Ambivali', 'Andheri East', 'Andheri West', 'Anjurdive', 'Asangaon', 'Babulnath Road', 'Badlapur', 'Badlapur East', 'Badlapur West', 'Bandra East', 'Bandra Kurla Complex', 'Bandra West', 'Belapur', 'Bhandup East', 'Bhandup West', 'Bhayandar East', 'Bhayandar West', 'Bhiwandi', 'Boisar', 'Borivali', 'Borivali East', 'Borivali West', 'Byculla', 'Chembur', 'Colaba', 'Cuffe Parade', 'Dadar East', 'Dadar West', 'Dahisar', 'Dahisar East', 'Dahisar West', 'Deonar', 'Dharavi', 'Diva', 'Dombivali', 'Dombivali East', 'Dombivli (West)', 'Dronagiri', 'Fort', 'Ghansoli', 'Ghatkopar East', 'Ghatkopar West', 'Girgaon', 'Goregaon East', 'Goregaon West', 'Govandi', 'Hiranandani Estates', 'Jogeshwari East', 'Jogeshwari West', 'Juhu', 'Juinagar', 'Kalamboli', 'Kalher', 'Kalwa', 'Kalyan East', 'Kalyan West', 'Kamothe', 'Kandivali East', 'Kandivali West', 'Kanjurmarg', 'Kanjurmarg East', 'Karanjade', 'Karjat', 'Kasheli', 'Kewale', 'Khar', 'Khar West', 'Khardi', 'Kharghar', 'Khopoli', 'Koper Khairane', 'Koproli', 'Kurla', 'Kurla East', 'Lower Parel', 'MATUNGA WEST', 'Mahalaxmi', 'Mahavir Nagar', 'Mahim', 'Mahim West', 'Malad East', 'Malad West', 'Manpada', 'Marine Lines', 'Matunga', 'Mazagaon', 'Mazgaon', 'Mira Road', 'Mira Road East', 'Mulund', 'Mulund East', 'Mulund West', 'Mumbai Central', 'Nahur East', 'Naigaon East', 'Nala Sopara', 'Nalasopara East', 'Nalasopara West', 'Napeansea Road', 'Naupada', 'Navade', 'Neral', 'Nerul', 'Nilje Gaon', 'Owale', 'Palava', 'Palghar', 'Panch Pakhdi', 'Panvel', 'Parel', 'Patlipada', 'Peddar Road', 'Powai', 'Prabhadevi', 'Rabale', 'Rasayani', 'Sanpada', 'Santacruz East', 'Santacruz West', 'Saphale', 'Seawoods', 'Sector 12 Kharghar', 'Sector 17 Ulwe', 'Sector 19 Kamothe', 'Sector 19 Kharghar', 'Sector 20 Kamothe', 'Sector 21 Kamothe', 'Sector 22 Kamothe', 'Sector 23 Ulwe', 'Sector 30 Kharghar', 'Sector-12 Kamothe', 'Sector-9 Ulwe', 'Sewri', 'Shahapur', 'Shil Phata', 'Sion', 'Taloja', 'Taloje', 'Tardeo', 'Thane East', 'Thane West', 'Tilak Nagar', 'Titwala', 'Ulhasnagar', 'Ulwe', 'Umroli', 'Vangani', 'Vasai', 'Vasai east', 'Vashi', 'Vasind', 'Vichumbe', 'Vikhroli', 'Vikroli East', 'Ville Parle East', 'Ville Parle West', 'Virar', 'Virar East', 'Virar West', 'Wadala', 'Worli', 'kandivali', 'kasaradavali thane west']
df_unique = pd.DataFrame(unique_values, columns=['region'])
df_unique['Unnamed: 0'] = df_unique.index

# Use replace method to replace region values with integer indices
data['Unnamed: 0'] = data['region'].replace(dict(zip(df_unique['region'], df_unique['Unnamed: 0'])))
# Out:
# C:\Users\mittr\AppData\Local\Temp\ipykernel_6868\523326049.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Unnamed: 0'] = data['region'].replace(dict(zip(df_unique['region'], df_unique['Unnamed: 0'])))

# %%
data['Unnamed: 0'].unique
# Out:
# <bound method Series.unique of 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 53739    167
# 53740    167
# 53741    167
# 53742    167
# 53743    167
# Name: Unnamed: 0, Length: 53744, dtype: int64>

# %%
data.to_csv('Cleaned_data.csv', index=False)

# %%
data.describe()
# Out:
#          Unnamed: 0           bhk          type          area         price  \
# count  53744.000000  53744.000000  53744.000000  53744.000000  53744.000000
# mean      89.012262      1.987645      1.017100   1053.032283     29.599907
# std       47.328097      0.908908      0.175711    648.558322     33.245023
# min        0.000000      1.000000      1.000000    300.000000      1.000000
# 25%       53.000000      1.000000      1.000000    670.000000      1.750000
# 50%       93.000000      2.000000      1.000000    927.000000      4.750000
# 75%      145.000000      3.000000      1.000000   1200.000000     60.000000
# max      167.000000     10.000000      5.000000  16000.000000     99.990000
#
#         money in Cr
# count  53744.000000
# mean       1.597082
# std        1.841076
# min        0.119100
# 25%        0.650000
# 50%        1.100000
# 75%        1.900000
# max       55.550000

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train_scaled)
X_test_poly = poly.transform(X_test_scaled)

# %%
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)
rf_regressor.fit(X_train_poly, Y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
Y_pred_rf = rf_regressor.predict(X_test_poly)

# %%
print("Random Forest Regressor:", r2_score(Y_test, Y_pred_rf))
# Out:
# Random Forest Regressor: 0.9356409485589939

# %%
import pickle
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor()

# %%
with open('random_forest_model.pkl', 'wb') as file:
    pickle.dump(rf_model, file)

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# Assuming you have already loaded your data into X_train and y_train
# X_train is your feature matrix and y_train is your target vector

# Initialize the RandomForestRegressor
model = RandomForestRegressor()

# Fit the model to your training data
model.fit(X_train, Y_train)

# Get feature importances
importance = model.feature_importances_

# Get the column names
feature_names = X_train.columns

# Pair feature importances with column names
feature_importance_dict = dict(zip(feature_names, importance))

# Sort features by their importance
sorted_importance = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)

# Print sorted feature importances
for feature, importance in sorted_importance:
    print(f"{feature}: {importance}")
# Out:
# area: 0.6319975750948963
# Unnamed: 0: 0.25480363237462045
# bhk: 0.11035446238715084
# type: 0.00284433014333254

# %%
data['Unnamed: 0'].unique
# Out:
# <bound method Series.unique of 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 53739    167
# 53740    167
# 53741    167
# 53742    167
# 53743    167
# Name: Unnamed: 0, Length: 53744, dtype: int64>

# %%
data['type'].unique
# Out:
# <bound method Series.unique of 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 53739    1
# 53740    1
# 53741    1
# 53742    1
# 53743    1
# Name: type, Length: 53744, dtype: int64>

# %%
import matplotlib.pyplot as plt

# Assuming Y_test contains the actual values and Y_pred contains the predicted values
# Replace Y_test and Y_pred with your actual and predicted values

plt.figure(figsize=(10, 6))
plt.scatter(Y_test, Y_pred_rf, color='blue', label='Actual vs. Predicted')
plt.plot([min(Y_test), max(Y_test)], [min(Y_test), max(Y_test)], '--', color='red', label='Perfect Prediction')
plt.title('Actual vs. Predicted Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.show()
